# %%
import pandas as pd
from nba_api.stats.endpoints import playergamelogs, teamgamelogs
import statistics
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 40)

# %%
gamelogs = playergamelogs.PlayerGameLogs(season_nullable='2019-20')
teamlogs = teamgamelogs.TeamGameLogs(season_nullable='2019-20')

# %%
playerlogs = gamelogs.get_data_frames()[0]
teamlogs = teamlogs.get_data_frames()[0]

# %%
teamlogs
# Out:
#      SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION             TEAM_NAME  \
# 0        2019-20  1610612743               DEN        Denver Nuggets
# 1        2019-20  1610612746               LAC           LA Clippers
# 2        2019-20  1610612745               HOU       Houston Rockets
# 3        2019-20  1610612748               MIA            Miami Heat
# 4        2019-20  1610612761               TOR       Toronto Raptors
# ...          ...         ...               ...                   ...
# 2113     2019-20  1610612753               ORL         Orlando Magic
# 2114     2019-20  1610612746               LAC           LA Clippers
# 2115     2019-20  1610612761               TOR       Toronto Raptors
# 2116     2019-20  1610612740               NOP  New Orleans Pelicans
# 2117     2019-20  1610612747               LAL    Los Angeles Lakers
#
#          GAME_ID            GAME_DATE      MATCHUP WL   MIN  FGM  FGA  FG_PCT  \
# ...

# %%
playerlogs
# Out:
#       SEASON_YEAR  PLAYER_ID     PLAYER_NAME  NICKNAME     TEAM_ID  \
# 0         2019-20     201188      Marc Gasol      Marc  1610612761
# 1         2019-20    1628778     Paul Watson      Paul  1610612761
# 2         2019-20    1629611    Terance Mann   Terance  1610612746
# 3         2019-20    1628408       PJ Dozier        PJ  1610612743
# 4         2019-20     203460  Andre Roberson     Andre  1610612760
# ...           ...        ...             ...       ...         ...
# 22388     2019-20     200768      Kyle Lowry      Kyle  1610612761
# 22389     2019-20    1629740    Nicolo Melli    Nicolo  1610612740
# 22390     2019-20     201586     Serge Ibaka     Serge  1610612761
# 22391     2019-20    1628366      Lonzo Ball     Lonzo  1610612740
# 22392     2019-20     203210  JaMychal Green  JaMychal  1610612746
#
#       TEAM_ABBREVIATION              TEAM_NAME     GAME_ID  \
# 0                   TOR        Toronto Raptors  0021901318
# ...
