# %%
import pandas as pd
from nba_api.stats.endpoints import playergamelogs, teamgamelogs
import statistics
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 40)

# %%
gamelogs = playergamelogs.PlayerGameLogs(season_nullable='2019-20')
teamlogs = teamgamelogs.TeamGameLogs(season_nullable='2019-20')

# %%
playerlogs = gamelogs.get_data_frames()[0]
teamlogs = teamlogs.get_data_frames()[0]

# %%
teamlogs
# Out:
#      SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION             TEAM_NAME  \
# 0        2019-20  1610612743               DEN        Denver Nuggets
# 1        2019-20  1610612746               LAC           LA Clippers
# 2        2019-20  1610612745               HOU       Houston Rockets
# 3        2019-20  1610612748               MIA            Miami Heat
# 4        2019-20  1610612761               TOR       Toronto Raptors
# ...          ...         ...               ...                   ...
# 2113     2019-20  1610612753               ORL         Orlando Magic
# 2114     2019-20  1610612746               LAC           LA Clippers
# 2115     2019-20  1610612761               TOR       Toronto Raptors
# 2116     2019-20  1610612740               NOP  New Orleans Pelicans
# 2117     2019-20  1610612747               LAL    Los Angeles Lakers
#
#          GAME_ID            GAME_DATE      MATCHUP WL   MIN  FGM  FGA  FG_PCT  \
# ...

# %%
playerlogs
# Out:
#       SEASON_YEAR  PLAYER_ID     PLAYER_NAME  NICKNAME     TEAM_ID  \
# 0         2019-20     201188      Marc Gasol      Marc  1610612761
# 1         2019-20    1628778     Paul Watson      Paul  1610612761
# 2         2019-20    1629611    Terance Mann   Terance  1610612746
# 3         2019-20    1628408       PJ Dozier        PJ  1610612743
# 4         2019-20     203460  Andre Roberson     Andre  1610612760
# ...           ...        ...             ...       ...         ...
# 22388     2019-20     200768      Kyle Lowry      Kyle  1610612761
# 22389     2019-20    1629740    Nicolo Melli    Nicolo  1610612740
# 22390     2019-20     201586     Serge Ibaka     Serge  1610612761
# 22391     2019-20    1628366      Lonzo Ball     Lonzo  1610612740
# 22392     2019-20     203210  JaMychal Green  JaMychal  1610612746
#
#       TEAM_ABBREVIATION              TEAM_NAME     GAME_ID  \
# 0                   TOR        Toronto Raptors  0021901318
# ...

# %%
teams = teamlogs['TEAM_ABBREVIATION'].unique()
for i in teams:
    ids = teamlogs[teamlogs["TEAM_ABBREVIATION"]==i]["GAME_ID"]
    opponents = teamlogs["GAME_ID"].isin(ids)
    opponents = teamlogs[opponents]
    teamopp = opponents[opponents["TEAM_ABBREVIATION"]!=i]
    print(i + " " , round(statistics.mean(teamlogs[teamlogs["TEAM_ABBREVIATION"]==i]["PTS"]),4), round(statistics.stdev(teamlogs[teamlogs["TEAM_ABBREVIATION"]==i]["PTS"]),4))
    print(i + " opponets: " , round(statistics.mean(teamopp["PTS"]),4),round(statistics.stdev(teamopp["PTS"]),4))
# Out:
# OKC  110.4167 11.6942
# OKC opponets:  108.4306 10.9452
# MIA  112.0411 12.11
# MIA opponets:  109.0959 10.8694
# DEN  111.2877 11.1436
# DEN opponets:  109.1781 11.6623
# PHI  110.7397 11.5723
# PHI opponets:  108.3562 11.6968
# IND  109.4384 10.2943
# IND opponets:  107.4795 10.933
# HOU  117.8056 13.7222
# HOU opponets:  114.8472 11.3307
# LAC  116.3472 13.5627
# LAC opponets:  109.9028 13.2614
# TOR  112.75 12.5852
# TOR opponets:  106.5139 10.9003
# NOP  115.8472 10.9076
# NOP opponets:  117.1389 11.5433
# WAS  114.4167 13.036
# WAS opponets:  119.0833 14.2372
# LAL  113.4366 11.9997
# LAL opponets:  107.6479 11.5004
# BKN  111.7778 12.0014
# BKN opponets:  112.3472 12.5285
# MEM  112.6301 11.3951
# MEM opponets:  113.6986 13.179
# POR  114.973 11.2493
# POR opponets:  116.1216 10.8564
# PHX  113.6164 12.1182
# PHX opponets:  113.3973 10.4944
# MIL  118.6712 11.535
# MIL opponets:  108.589 13.0276
# DAL  117.0133 11.7456
# DAL opponets:  112.0667 11.9519
# ORL  107.274 13.6211
# ...

# %%
df3 = teamlogs.merge(right=teamlogs, left_on='GAME_ID', right_on='GAME_ID')b
df3
# Out:
#      SEASON_YEAR_x   TEAM_ID_x TEAM_ABBREVIATION_x           TEAM_NAME_x  \
# 0          2019-20  1610612761                 TOR       Toronto Raptors
# 1          2019-20  1610612761                 TOR       Toronto Raptors
# 2          2019-20  1610612743                 DEN        Denver Nuggets
# 3          2019-20  1610612743                 DEN        Denver Nuggets
# 4          2019-20  1610612748                 MIA            Miami Heat
# ...            ...         ...                 ...                   ...
# 4231       2019-20  1610612740                 NOP  New Orleans Pelicans
# 4232       2019-20  1610612747                 LAL    Los Angeles Lakers
# 4233       2019-20  1610612747                 LAL    Los Angeles Lakers
# 4234       2019-20  1610612746                 LAC           LA Clippers
# 4235       2019-20  1610612746                 LAC           LA Clippers
#
#          GAME_ID          GAME_DATE_x    MATCHUP_x WL_x  MIN_x  FGM_x  FGA_x  \
# ...

# %%
#df3.drop(df3[(df3['TEAM_NAME_x']) == (df3['TEAM_NAME_y'])], inplace = True)
com = df3[df3['TEAM_NAME_x']!=df3['TEAM_NAME_y']]
com
# Out:
#      SEASON_YEAR_x   TEAM_ID_x TEAM_ABBREVIATION_x           TEAM_NAME_x  \
# 1          2019-20  1610612761                 TOR       Toronto Raptors
# 2          2019-20  1610612743                 DEN        Denver Nuggets
# 5          2019-20  1610612748                 MIA            Miami Heat
# 6          2019-20  1610612754                 IND        Indiana Pacers
# 9          2019-20  1610612755                 PHI    Philadelphia 76ers
# ...            ...         ...                 ...                   ...
# 4226       2019-20  1610612764                 WAS    Washington Wizards
# 4229       2019-20  1610612761                 TOR       Toronto Raptors
# 4230       2019-20  1610612740                 NOP  New Orleans Pelicans
# 4233       2019-20  1610612747                 LAL    Los Angeles Lakers
# 4234       2019-20  1610612746                 LAC           LA Clippers
#
#          GAME_ID          GAME_DATE_x    MATCHUP_x WL_x  MIN_x  FGM_x  FGA_x  \
# ...

# %%
com["pace"]= 0.5*((com['FGA_x'] + 0.4*com['FTA_x'] - 1.07*(com['OREB_x']/(com['OREB_x'] + com['DREB_y']))*(com['FGA_x'] - com['FGM_x']) + com['TOV_x']) + (com['FGA_y'] + 0.4*(com['FTA_y']) - 1.07*(com['OREB_y'])/(com['OREB_y'] + com['DREB_x']))*(com['FGA_y'] - com['FGM_y']) + com['TOV_y'])
com["pace"]
# Out:
# <ipython-input-34-05f3566bf695>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com["pace"]= 0.5*((com['FGA_x'] + 0.4*com['FTA_x'] - 1.07*(com['OREB_x']/(com['OREB_x'] + com['DREB_y']))*(com['FGA_x'] - com['FGM_x']) + com['TOV_x']) + (com['FGA_y'] + 0.4*(com['FTA_y']) - 1.07*(com['OREB_y'])/(com['OREB_y'] + com['DREB_x']))*(com['FGA_y'] - com['FGM_y']) + com['TOV_y'])
# 1       2506.220213
# 2       2204.420213
# 5       2202.266038
# 6       2790.266038
# 9       2003.069311
#            ...
# 4226    1888.187308
# 4229    3303.387574
# 4230    3659.387574
# 4233    1817.187558
# 4234    2290.687558
# Name: pace, Length: 2118, dtype: float64

# %%
com["pace2"] = (com["FGA_x"] + .44*com["FTA_x"] - com["OREB_x"] + com["TOV_x"])/2
com["pace2"]
# Out:
# <ipython-input-36-a99f46043f45>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com["pace2"] = (com["FGA_x"] + .44*com["FTA_x"] - com["OREB_x"] + com["TOV_x"])/2
# 1       51.08
# 2       52.06
# 5       51.94
# 6       50.92
# 9       52.34
#         ...
# 4226    53.46
# 4229    60.36
# 4230    56.90
# 4233    50.12
# 4234    47.28
# Name: pace2, Length: 2118, dtype: float64

# %%
com["FGA_x"]
# Out:
# 1        90
# 2        87
# 5        87
# 6        89
# 9        87
#        ...
# 4226     93
# 4229    103
# 4230    102
# 4233     85
# 4234     81
# Name: FGA_x, Length: 2118, dtype: int64
