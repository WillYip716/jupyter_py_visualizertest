# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./data/merged_data2014_2018.csv',delimiter = ',')

# %%
data.head()
# Out:
#    year  week vteam hteam  vscore  hscore  vospread  hospread  ouopen  \
# 0  2007     1    NO   IND      10      41       5.5      -5.5    50.5
# 1  2007     1    KC   HOU       3      20      -0.0       0.0    38.5
# 2  2007     1   DEN   BUF      15      14      -3.0       3.0    37.0
# 3  2007     1   PIT   CLE      34       7      -4.5       4.5    37.5
# 4  2007     1   TEN   JAX      13      10       6.5      -6.5    37.5
#
#    vcspread  ...  hST.RNK  hST.DVOA      vDAVE       vW-L      hDAVE  \
# 0       5.5  ...     23.0     -0.6%  undefined  undefined  undefined
# 1       3.0  ...     27.0     -1.2%  undefined  undefined  undefined
# 2      -3.0  ...      1.0      3.7%  undefined  undefined  undefined
# 3      -5.0  ...     10.0      0.6%  undefined  undefined  undefined
# 4       7.5  ...     19.0     -0.1%  undefined  undefined  undefined
#
#         hW-L  vLASTWEEK  hLASTWEEK  vWEI.DVOA hWEI.DVOA
# 0  undefined  undefined  undefined        NaN       NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3328 entries, 0 to 3327
# Data columns (total 36 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         3328 non-null   int64
#  1   week         3328 non-null   int64
#  2   vteam        3328 non-null   object
#  3   hteam        3328 non-null   object
#  4   vscore       3328 non-null   int64
#  5   hscore       3328 non-null   int64
#  6   vospread     3328 non-null   float64
#  7   hospread     3328 non-null   float64
#  8   ouopen       3328 non-null   float64
#  9   vcspread     3328 non-null   float64
#  10  hcspread     3328 non-null   float64
#  11  ouclose      3328 non-null   float64
#  12  vTOTAL.RNK   3296 non-null   float64
#  13  vTOTAL.DVOA  3296 non-null   object
#  14  vOFF.RNK     3296 non-null   float64
#  15  vOFF.DVOA    3296 non-null   object
#  16  vDEF.RNK     3296 non-null   float64
#  17  vDEF.DVOA    3296 non-null   object
# ...

# %%
data =data.dropna()
xvaxis = data['vOFF.DVOA']
yvaxis = data['vscore']
xvaxis = xvaxis.dropna().astype(str).apply(lambda x:x[:-1]).astype(float)


plt.scatter(xvaxis,yvaxis,color='b')
plt.xlabel('visitor offensive dvoa')
plt.ylabel('score')
plt.rcParams["figure.figsize"] = (10,10)
