# %%
import pandas as pd
import numpy as np
import statistics
import csv

# %%
pd.set_option("display.max_columns", None)
data = pd.read_csv("data/nba2019-20_pbp.csv")
data.head()
# Out:
#                             URL GameType                         Location  \
# 0  /boxscores/201910220TOR.html  regular  Scotiabank Arena Toronto Canada
# 1  /boxscores/201910220TOR.html  regular  Scotiabank Arena Toronto Canada
# 2  /boxscores/201910220TOR.html  regular  Scotiabank Arena Toronto Canada
# 3  /boxscores/201910220TOR.html  regular  Scotiabank Arena Toronto Canada
# 4  /boxscores/201910220TOR.html  regular  Scotiabank Arena Toronto Canada
#
#               Date     Time WinningTeam  Quarter  SecLeft AwayTeam  \
# 0  October 22 2019  8:00 PM         TOR        1      720      NOP
# 1  October 22 2019  8:00 PM         TOR        1      708      NOP
# 2  October 22 2019  8:00 PM         TOR        1      707      NOP
# 3  October 22 2019  8:00 PM         TOR        1      707      NOP
# 4  October 22 2019  8:00 PM         TOR        1      689      NOP
#
#                                             AwayPlay  AwayScore HomeTeam  \
# ...

# %%
player = data[(data['Shooter'].str.contains("K. Leonard",na=False))]
player = lonzo[lonzo['ShotOutcome']=='make']

print("makes " , player.shape[0])
print("all " , player.shape[0])
# Out:
# makes  663
# all  663

# %%
players = data.groupby('Shooter')
#players.groups.keys()
player = players.get_group('A. Wiggins - wiggian01')
player
# Out:
#                                  URL GameType  \
# 2479    /boxscores/201910230BRK.html  regular
# 2488    /boxscores/201910230BRK.html  regular
# 2495    /boxscores/201910230BRK.html  regular
# 2499    /boxscores/201910230BRK.html  regular
# 2503    /boxscores/201910230BRK.html  regular
# ...                              ...      ...
# 455551  /boxscores/202003100GSW.html  regular
# 455570  /boxscores/202003100GSW.html  regular
# 455612  /boxscores/202003100GSW.html  regular
# 455643  /boxscores/202003100GSW.html  regular
# 455648  /boxscores/202003100GSW.html  regular
#
#                                      Location             Date      Time  \
# 2479        Barclays Center Brooklyn New York  October 23 2019   7:30 PM
# 2488        Barclays Center Brooklyn New York  October 23 2019   7:30 PM
# 2495        Barclays Center Brooklyn New York  October 23 2019   7:30 PM
# 2499        Barclays Center Brooklyn New York  October 23 2019   7:30 PM
# ...

# %%
#regular = player.groupby('GameType').get_group('regular')
player.groupby('GameType').groups.keys()
# Out:
# dict_keys(['regular'])
