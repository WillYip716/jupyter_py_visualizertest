# %%
import pandas as pd
from nba_api.stats.endpoints import playercareerstats, teamyearbyyearstats, commonallplayers

# %%
pd.set_option('display.max_columns', 40)
pd.set_option('display.max_rows', 40)
career = playercareerstats.PlayerCareerStats(player_id='203076', per_mode36="Per36")


career.get_data_frames()[0].iloc[-1:]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 8     203076   2020-21        00  1610612747               LAL        28.0
#
#    GP  GS    MIN  FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  \
# 8  23  23  755.0  9.7  18.3   0.533   0.8   2.8    0.293  4.4  6.2   0.715
#
#    OREB  DREB  REB  AST  STL  BLK  TOV   PF   PTS
# 8   2.2   7.0  9.2  3.3  1.5  2.0  2.1  2.0  24.7

# %%
#team = teamyearbyyearstats.TeamYearByYearStats(team_id='1610612739', season_type_all_star='Regular Season', per_mode_simple='PerGame')
#team.get_data_frames()[0]

players = commonallplayers.CommonAllPlayers(season='2020-21',is_only_current_season=1)
players = players.get_data_frames()[0]

cond1 = players['GAMES_PLAYED_FLAG']=="Y"
cond2 = players['ROSTERSTATUS']==1
cond = cond1 & cond2
players[cond]
# Out:
#      PERSON_ID DISPLAY_LAST_COMMA_FIRST DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 0      1630173        Achiuwa, Precious   Precious Achiuwa             1
# 2       203500            Adams, Steven       Steven Adams             1
# 3      1628389             Adebayo, Bam        Bam Adebayo             1
# 4       200746       Aldridge, LaMarcus  LaMarcus Aldridge             1
# 5      1630234       Alexander, Ty-Shon  Ty-Shon Alexander             1
# ..         ...                      ...                ...           ...
# 511    1626153            Wright, Delon       Delon Wright             1
# 512     201152          Young, Thaddeus     Thaddeus Young             1
# 513    1629027              Young, Trae         Trae Young             1
# 514     203469             Zeller, Cody        Cody Zeller             1
# 515    1627826             Zubac, Ivica        Ivica Zubac             1
#
#     FROM_YEAR TO_YEAR         PLAYERCODE     TEAM_ID    TEAM_CITY TEAM_NAME  \
# ...
