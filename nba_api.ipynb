# %%
import pandas as pd
from nba_api.stats.endpoints import playergamelogs, boxscoretraditionalv2, playercareerstats, teamyearbyyearstats, commonallplayers, leaguedashplayerstats,commonplayerinfo, scoreboard
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 40)

# %%
#boxscore = boxscoretraditionalv2.BoxScoreTraditionalV2(game_id='0021700307')
#boxscore
gamelogs = playergamelogs.PlayerGameLogs(season_nullable='2019-20')

# %%
playerlogs = gamelogs.get_data_frames()[0]
playerlogs[playerlogs['PLAYER_NAME']=='Bryn Forbes']
# Out:
#       SEASON_YEAR  PLAYER_ID  PLAYER_NAME NICKNAME     TEAM_ID  \
# 2136      2019-20    1627854  Bryn Forbes     Bryn  1610612759
# 2228      2019-20    1627854  Bryn Forbes     Bryn  1610612759
# 2685      2019-20    1627854  Bryn Forbes     Bryn  1610612759
# 3181      2019-20    1627854  Bryn Forbes     Bryn  1610612759
# 3335      2019-20    1627854  Bryn Forbes     Bryn  1610612759
# ...           ...        ...          ...      ...         ...
# 20773     2019-20    1627854  Bryn Forbes     Bryn  1610612759
# 20957     2019-20    1627854  Bryn Forbes     Bryn  1610612759
# 21365     2019-20    1627854  Bryn Forbes     Bryn  1610612759
# 21753     2019-20    1627854  Bryn Forbes     Bryn  1610612759
# 22209     2019-20    1627854  Bryn Forbes     Bryn  1610612759
#
#       TEAM_ABBREVIATION          TEAM_NAME     GAME_ID            GAME_DATE  \
# 2136                SAS  San Antonio Spurs  0021900965  2020-03-10T00:00:00
# ...

# %%
#career = playercareerstats.PlayerCareerStats(player_id='203076', per_mode36="Per36")
#career.get_data_frames()[0].iloc[-1:]

#playerinfo = commonplayerinfo.CommonPlayerInfo(player_id='1628988')
#playerinfo.get_data_frames()[0].iloc[-1:]

scores = scoreboard.Scoreboard(day_offset='0',game_date='2021-05-1',league_id='00')
scores = scores.get_data_frames()[1]
results = dict(zip(scores.TEAM_ABBREVIATION, scores.PTS))
results
# Out:
# {'DET': 94,
#  'CHA': 107,
#  'GSW': 113,
#  'HOU': 87,
#  'CHI': 97,
#  'ATL': 108,
#  'MIA': 124,
#  'CLE': 107,
#  'MEM': 111,
#  'ORL': 112,
#  'NOP': 140,
#  'MIN': 136,
#  'IND': 152,
#  'OKC': 95,
#  'WAS': 124,
#  'DAL': 125,
#  'TOR': 102,
#  'UTA': 106,
#  'DEN': 110,
#  'LAC': 104}

# %%
#team = teamyearbyyearstats.TeamYearByYearStats(team_id='1610612739', season_type_all_star='Regular Season', per_mode_simple='PerGame')
#team.get_data_frames()[0]

players = commonallplayers.CommonAllPlayers(season='2020-21',is_only_current_season=1)
players = players.get_data_frames()[0]

cond1 = players['GAMES_PLAYED_FLAG']=="Y"
cond2 = players['ROSTERSTATUS']==1
cond = cond1 & cond2
playerslist = players["PERSON_ID"].to_numpy()

playerslist
# Out:
# array([1630173, 1629121,  203500, 1628389,  200746, 1630234, 1629638,
#        1628960, 1628386,  202329,  203937,  203507, 1628961,  203648,
#           2546, 1630175, 1628384, 1627853,    2772,  201571, 1630166,
#        1629028, 1628962, 1628407, 1628963, 1630163, 1628366, 1628964,
#        1630217,  203084, 1629628,  203115, 1628966,  201587,  203382,
#         203145, 1629647,  203078, 1627736, 1628395, 1627761,  202722,
#         201976, 1630180, 1630189,  203920, 1629048,  202687,  202357,
#         202339, 1629833,  203992,  202711, 1629626, 1629716, 1629648,
#        1629067, 1626164, 1628449, 1628968,  202340, 1628396, 1629714,
#        1629649, 1628969, 1628970, 1629052, 1627763, 1628415, 1628971,
#        1627759, 1629650, 1628425, 1628972, 1628973, 1628418,  203493,
#         203504,  202692,  202710,  203998, 1629719,  203484, 1630267,
#        1628427,  203991, 1630176, 1628975, 1628976,  203487, 1627936,
# ...

# %%
players = leaguedashplayerstats.LeagueDashPlayerStats(season='2020-21',per_mode_detailed="PerGame",season_type_all_star="Regular Season", player_position_abbreviation_nullable="F")
players = players.get_data_frames()[0]
players
# Out:
#      PLAYER_ID      PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION   AGE  GP   W  \
# 0       203932     Aaron Gordon  1610612743               DEN  25.0  33  17
# 1      1630174    Aaron Nesmith  1610612738               BOS  21.0  30  16
# 2      1627846      Abdel Nader  1610612756               PHX  27.0  24  16
# 3       201143       Al Horford  1610612760               OKC  34.0  28  11
# 4       202329  Al-Farouq Aminu  1610612741               CHI  30.0  18   5
# ..         ...              ...         ...               ...   ...  ..  ..
# 285    1630214   Xavier Tillman  1610612763               MEM  22.0  41  20
# 286    1629139    Yuta Watanabe  1610612761               TOR  26.0  35  18
# 287     203897      Zach LaVine  1610612741               CHI  26.0  51  22
# 288    1630192       Zeke Nnaji  1610612743               DEN  20.0  34  24
# 289    1629627  Zion Williamson  1610612740               NOP  20.0  48  23
#
# ...

# %%
for i, j in players.iterrows():
    print(j.PLAYER_NAME + " " + str(j.NBA_FANTASY_PTS_RANK))
# Out:
# Aaron Gordon 79
# Aaron Holiday 328
# Aaron Nesmith 398
# Abdel Nader 320
# Adam Mokoka 466
# Al Horford 66
# Al-Farouq Aminu 247
# Alec Burks 140
# Aleksej Pokusevski 221
# Alen Smailagic 463
# Alex Caruso 266
# Alex Len 273
# Alfonzo McKinnie 451
# Alize Johnson 84
# Amir Coffey 443
# Andre Drummond 26
# Andre Iguodala 269
# Andre Roberson 391
# Andrew Wiggins 70
# Anfernee Simons 304
# Anthony Davis 17
# Anthony Edwards 86
# Anthony Gill 453
# Anthony Lamb 415
# Anzejs Pasecniks 507
# Aron Baynes 286
# Ashton Hagans 505
# Austin Rivers 296
# Avery Bradley 278
# Axel Toupane 450
# Bam Adebayo 23
# Ben McLemore 324
# Ben Simmons 38
# Bismack Biyombo 254
# Blake Griffin 135
# Boban Marjanovic 357
# Bobby Portis 145
# Bogdan Bogdanovic 159
# Bojan Bogdanovic 155
# Bol Bol 445
# Brad Wanamaker 327
# Bradley Beal 15
# Brandon Clarke 112
# Brandon Goodwin 387
# Brandon Ingram 39
# Brian Bowen II 495
# Brodric Thomas 384
# Brook Lopez 146
# Bruce Brown 217
# Bruno Caboclo 423
# ...
